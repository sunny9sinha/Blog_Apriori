# %% [markdown]
# <a href="https://colab.research.google.com/github/sunny9sinha/Blog_Apriori/blob/main/Apriori_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Load "store_data.csv" dataset
store_data_df = pd.read_csv("/content/store_data.csv", header=None)

# Preprocess dataset
transactions = []
for i in range(len(store_data_df)):
    transactions.append([str(store_data_df.values[i,j]) for j in range(len(store_data_df.columns))])

# Transform dataset into one-hot encoding
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# Generate frequent itemsets with minimum support of 0.01
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# Generate association rules with minimum confidence of 0.5
association_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# %%
# Print frequent itemsets and association rules
frequent_itemsets
# Out:
#       support                                      itemsets
# 0    0.020397                                     (almonds)
# 1    0.033329                                     (avocado)
# 2    0.010799                              (barbecue sauce)
# 3    0.014265                                   (black tea)
# 4    0.011465                                  (body spray)
# ..        ...                                           ...
# 510  0.011065       (mineral water, ground beef, milk, nan)
# 511  0.017064  (nan, mineral water, ground beef, spaghetti)
# 512  0.015731         (nan, mineral water, milk, spaghetti)
# 513  0.010265    (nan, mineral water, olive oil, spaghetti)
# 514  0.011465     (nan, mineral water, pancakes, spaghetti)
#
# [515 rows x 2 columns]

# %%
association_rules
# Out:
#                                  antecedents           consequents  \
# 0                                  (almonds)                 (nan)
# 1                                  (avocado)                 (nan)
# 2                           (barbecue sauce)                 (nan)
# 3                                (black tea)                 (nan)
# 4                               (body spray)                 (nan)
# ..                                       ...                   ...
# 258                      (milk, ground beef)  (mineral water, nan)
# 259  (mineral water, spaghetti, ground beef)                 (nan)
# 260         (mineral water, milk, spaghetti)                 (nan)
# 261    (mineral water, olive oil, spaghetti)                 (nan)
# 262     (mineral water, spaghetti, pancakes)                 (nan)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.020397            0.999867  0.020264    0.993464  0.993597
# ...
